# %%
# Netflix Stock Price Analysis 📈
# --------------------------------
# Author: Havva Zimra
# Description: A simple exploratory data analysis (EDA) and visualization of Netflix stock prices over time.
# Dataset Source: Kaggle - Netflix Stock Price History

# 🧰 Importing Required Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# 🔍 Exploring Available Files in the Dataset Directory
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print("Found file:", os.path.join(dirname, filename))

# 📥 Load the Dataset
df = pd.read_csv("/kaggle/input/netflix-stock-price-history/Netflix_stock_data.csv")

# 🕒 Convert 'Date' to datetime format and sort chronologically
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

# 📊 Basic Exploratory Data Analysis
print("\n--- First 5 Rows ---")
print(df.head())

print("\n--- Data Info ---")
print(df.info())

print("\n--- Statistical Summary ---")
print(df.describe())

print("\n--- Missing Values ---")
print(df.isnull().sum())

print("\n--- Column Names ---")
print(df.columns.tolist())

# 📈 Visualization: Netflix Stock Closing Price Over Time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], color='red', linewidth=2)
plt.title('Netflix Stock Price Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Closing Price (USD)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Found file: /kaggle/input/netflix-stock-price-history/Netflix_stock_data.csv
#
# --- First 5 Rows ---
#         Date     Close      High       Low      Open     Volume
# 0 2002-05-23  1.196429  1.242857  1.145714  1.156429  104790000
# 1 2002-05-24  1.210000  1.225000  1.197143  1.214286   11104800
# 2 2002-05-28  1.157143  1.232143  1.157143  1.213571    6609400
# 3 2002-05-29  1.103571  1.164286  1.085714  1.164286    6757800
# 4 2002-05-30  1.071429  1.107857  1.071429  1.107857   10154200
#
# --- Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5817 entries, 0 to 5816
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5817 non-null   datetime64[ns]
#  1   Close   5817 non-null   float64
#  2   High    5817 non-null   float64
#  3   Low     5817 non-null   float64
#  4   Open    5817 non-null   float64
#  5   Volume  5817 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# ...
